# %%
# if you didnt install python-docx yet
# !pip install python-docx
# Out:
# Collecting python-docx
#   Obtaining dependency information for python-docx from https://files.pythonhosted.org/packages/5f/d8/6948f7ac00edf74bfa52b3c5e3073df20284bec1db466d13e668fe991707/python_docx-1.1.0-py3-none-any.whl.metadata
#   Downloading python_docx-1.1.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\renat\anaconda3\lib\site-packages (from python-docx) (4.9.3)
# Requirement already satisfied: typing-extensions in c:\users\renat\anaconda3\lib\site-packages (from python-docx) (4.7.1)
# Downloading python_docx-1.1.0-py3-none-any.whl (239 kB)
#    ---------------------------------------- 0.0/239.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/239.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/239.6 kB ? eta -:--:--
#    ------ -------------------------------- 41.0/239.6 kB 393.8 kB/s eta 0:00:01
#    ----------------- -------------------- 112.6/239.6 kB 819.2 kB/s eta 0:00:01
#    ---------------------------------------  235.5/239.6 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 239.6/239.6 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: python-docx
# Successfully installed python-docx-1.1.0

# %%
from docx import Document

# creating empty document in Python
document = Document()

example = 'Hello World (Variable)'

# here is where you'll have to edit 
text = f"""Hello World 1!
Hello World 2!
{example}
Hello World 3!
"""
paragraph = document. add_paragraph(text)

# saving and creating docx in Word
document.save('text.docx')

# now that we can add variables in our text, we can create systems that add variables from databases, or other functions
# so it is possible to automate several repetitives tasks...

# %%
# Formatting the text 
from docx.shared import Pt, RGBColor, Cm # Pt - letter size, RGBColor - color, Cm - size in centimeters 
from docx.enum.style import WD_STYLE_TYPE # with this you can create a custom formatting style

# creating a new style
paragraph.style = document.styles.add_style('TestStyle', WD_STYLE_TYPE.PARAGRAPH)
paragraph.style.font.name = 'Algerian'
paragraph.style.font.size = Pt(15)
paragraph.style.font.bold = True
paragraph.style.font.italic = True

# %%
paragraph = document.add_paragraph("""
New paragraph with new style
""", 'TestStyle')

# saving and creating docx in Word
document.save('text.docx')

# %%
# if you want to use a pre-existing style, you can check all styles available with a for loop
for style in document.styles:
    print(style)
# Out:
# _ParagraphStyle('Normal') id: 1864806314576
# _ParagraphStyle('Header') id: 1864805408720
# <docx.styles.style.CharacterStyle object at 0x000001B22F1E3250>
# _ParagraphStyle('Footer') id: 1864805408720
# <docx.styles.style.CharacterStyle object at 0x000001B22F1E3250>
# _ParagraphStyle('Heading 1') id: 1864805408720
# _ParagraphStyle('Heading 2') id: 1864806314576
# _ParagraphStyle('Heading 3') id: 1864805408720
# _ParagraphStyle('Heading 4') id: 1864806314576
# _ParagraphStyle('Heading 5') id: 1864805408720
# _ParagraphStyle('Heading 6') id: 1864806314576
# _ParagraphStyle('Heading 7') id: 1864805408720
# _ParagraphStyle('Heading 8') id: 1864806314576
# _ParagraphStyle('Heading 9') id: 1864805408720
# <docx.styles.style.CharacterStyle object at 0x000001B22F1E3250>
# _TableStyle('Normal Table') id: 1864805408720
# <docx.styles.style._NumberingStyle object at 0x000001B22F1E3250>
# _ParagraphStyle('No Spacing') id: 1864805408720
# <docx.styles.style.CharacterStyle object at 0x000001B22F1E3250>
# <docx.styles.style.CharacterStyle object at 0x000001B22F105FD0>
# <docx.styles.style.CharacterStyle object at 0x000001B22F1E3250>
# _ParagraphStyle('Title') id: 1864805408720
# <docx.styles.style.CharacterStyle object at 0x000001B22F1E3250>
# _ParagraphStyle('Subtitle') id: 1864805408720
# <docx.styles.style.CharacterStyle object at 0x000001B22F1E3250>
# _ParagraphStyle('List Paragraph') id: 1864805408720
# _ParagraphStyle('Body Text') id: 1864806314576
# <docx.styles.style.CharacterStyle object at 0x000001B22F105FD0>
# _ParagraphStyle('Body Text 2') id: 1864806314576
# <docx.styles.style.CharacterStyle object at 0x000001B22F105FD0>
# _ParagraphStyle('Body Text 3') id: 1864806314576
# <docx.styles.style.CharacterStyle object at 0x000001B22F105FD0>
# _ParagraphStyle('List') id: 1864806314576
# _ParagraphStyle('List 2') id: 1864805408720
# _ParagraphStyle('List 3') id: 1864806314576
# _ParagraphStyle('List Bullet') id: 1864805408720
# _ParagraphStyle('List Bullet 2') id: 1864806314576
# _ParagraphStyle('List Bullet 3') id: 1864805408720
# _ParagraphStyle('List Number') id: 1864806314576
# _ParagraphStyle('List Number 2') id: 1864805408720
# _ParagraphStyle('List Number 3') id: 1864806314576
# _ParagraphStyle('List Continue') id: 1864805408720
# _ParagraphStyle('List Continue 2') id: 1864806314576
# _ParagraphStyle('List Continue 3') id: 1864805408720
# _ParagraphStyle('macro') id: 1864806314576
# <docx.styles.style.CharacterStyle object at 0x000001B22F105FD0>
# _ParagraphStyle('Quote') id: 1864806314576
# <docx.styles.style.CharacterStyle object at 0x000001B22F105FD0>
# <docx.styles.style.CharacterStyle object at 0x000001B22F1E3250>
# <docx.styles.style.CharacterStyle object at 0x000001B22F105FD0>
# <docx.styles.style.CharacterStyle object at 0x000001B22F1E3250>
# <docx.styles.style.CharacterStyle object at 0x000001B22F105FD0>
# <docx.styles.style.CharacterStyle object at 0x000001B22F1E3250>
# <docx.styles.style.CharacterStyle object at 0x000001B22F105FD0>
# _ParagraphStyle('Caption') id: 1864806314576
# <docx.styles.style.CharacterStyle object at 0x000001B22F105FD0>
# <docx.styles.style.CharacterStyle object at 0x000001B22F1E3250>
# _ParagraphStyle('Intense Quote') id: 1864805408720
# <docx.styles.style.CharacterStyle object at 0x000001B22F1E3250>
# <docx.styles.style.CharacterStyle object at 0x000001B22F105FD0>
# <docx.styles.style.CharacterStyle object at 0x000001B22F1E3250>
# <docx.styles.style.CharacterStyle object at 0x000001B22F105FD0>
# <docx.styles.style.CharacterStyle object at 0x000001B22F1E3250>
# <docx.styles.style.CharacterStyle object at 0x000001B22F105FD0>
# _ParagraphStyle('TOC Heading') id: 1864806314576
# _TableStyle('Table Grid') id: 1864805408720
# _TableStyle('Light Shading') id: 1864806314576
# _TableStyle('Light Shading Accent 1') id: 1864805408720
# _TableStyle('Light Shading Accent 2') id: 1864806314576
# _TableStyle('Light Shading Accent 3') id: 1864805408720
# _TableStyle('Light Shading Accent 4') id: 1864806314576
# _TableStyle('Light Shading Accent 5') id: 1864805408720
# _TableStyle('Light Shading Accent 6') id: 1864806314576
# _TableStyle('Light List') id: 1864805408720
# _TableStyle('Light List Accent 1') id: 1864806782608
# _TableStyle('Light List Accent 2') id: 1864805408720
# _TableStyle('Light List Accent 3') id: 1864806782608
# _TableStyle('Light List Accent 4') id: 1864805408720
# _TableStyle('Light List Accent 5') id: 1864806782608
# _TableStyle('Light List Accent 6') id: 1864805408720
# _TableStyle('Light Grid') id: 1864806782608
# _TableStyle('Light Grid Accent 1') id: 1864805408720
# _TableStyle('Light Grid Accent 2') id: 1864806782608
# _TableStyle('Light Grid Accent 3') id: 1864805408720
# _TableStyle('Light Grid Accent 4') id: 1864806782608
# _TableStyle('Light Grid Accent 5') id: 1864805408720
# _TableStyle('Light Grid Accent 6') id: 1864806782608
# _TableStyle('Medium Shading 1') id: 1864805408720
# _TableStyle('Medium Shading 1 Accent 1') id: 1864806782608
# _TableStyle('Medium Shading 1 Accent 2') id: 1864805408720
# _TableStyle('Medium Shading 1 Accent 3') id: 1864806782608
# _TableStyle('Medium Shading 1 Accent 4') id: 1864805408720
# _TableStyle('Medium Shading 1 Accent 5') id: 1864806782608
# _TableStyle('Medium Shading 1 Accent 6') id: 1864805408720
# _TableStyle('Medium Shading 2') id: 1864806782608
# _TableStyle('Medium Shading 2 Accent 1') id: 1864805408720
# _TableStyle('Medium Shading 2 Accent 2') id: 1864806782608
# _TableStyle('Medium Shading 2 Accent 3') id: 1864805408720
# _TableStyle('Medium Shading 2 Accent 4') id: 1864806782608
# _TableStyle('Medium Shading 2 Accent 5') id: 1864805408720
# _TableStyle('Medium Shading 2 Accent 6') id: 1864806782608
# _TableStyle('Medium List 1') id: 1864805408720
# _TableStyle('Medium List 1 Accent 1') id: 1864806782608
# _TableStyle('Medium List 1 Accent 2') id: 1864805408720
# _TableStyle('Medium List 1 Accent 3') id: 1864806782608
# _TableStyle('Medium List 1 Accent 4') id: 1864805408720
# _TableStyle('Medium List 1 Accent 5') id: 1864806782608
# _TableStyle('Medium List 1 Accent 6') id: 1864805408720
# _TableStyle('Medium List 2') id: 1864806782608
# _TableStyle('Medium List 2 Accent 1') id: 1864805408720
# _TableStyle('Medium List 2 Accent 2') id: 1864806782608
# _TableStyle('Medium List 2 Accent 3') id: 1864805408720
# _TableStyle('Medium List 2 Accent 4') id: 1864806782608
# _TableStyle('Medium List 2 Accent 5') id: 1864805408720
# _TableStyle('Medium List 2 Accent 6') id: 1864806782608
# _TableStyle('Medium Grid 1') id: 1864805408720
# _TableStyle('Medium Grid 1 Accent 1') id: 1864806782608
# _TableStyle('Medium Grid 1 Accent 2') id: 1864805408720
# _TableStyle('Medium Grid 1 Accent 3') id: 1864806782608
# _TableStyle('Medium Grid 1 Accent 4') id: 1864805408720
# _TableStyle('Medium Grid 1 Accent 5') id: 1864806782608
# _TableStyle('Medium Grid 1 Accent 6') id: 1864805408720
# _TableStyle('Medium Grid 2') id: 1864806782608
# _TableStyle('Medium Grid 2 Accent 1') id: 1864805408720
# _TableStyle('Medium Grid 2 Accent 2') id: 1864806782608
# _TableStyle('Medium Grid 2 Accent 3') id: 1864805408720
# _TableStyle('Medium Grid 2 Accent 4') id: 1864806782608
# _TableStyle('Medium Grid 2 Accent 5') id: 1864805408720
# _TableStyle('Medium Grid 2 Accent 6') id: 1864806782608
# _TableStyle('Medium Grid 3') id: 1864805408720
# _TableStyle('Medium Grid 3 Accent 1') id: 1864806782608
# _TableStyle('Medium Grid 3 Accent 2') id: 1864805408720
# _TableStyle('Medium Grid 3 Accent 3') id: 1864806782608
# _TableStyle('Medium Grid 3 Accent 4') id: 1864805408720
# _TableStyle('Medium Grid 3 Accent 5') id: 1864806782608
# _TableStyle('Medium Grid 3 Accent 6') id: 1864805408720
# _TableStyle('Dark List') id: 1864806782608
# _TableStyle('Dark List Accent 1') id: 1864805408720
# _TableStyle('Dark List Accent 2') id: 1864806782608
# _TableStyle('Dark List Accent 3') id: 1864805408720
# _TableStyle('Dark List Accent 4') id: 1864806782608
# _TableStyle('Dark List Accent 5') id: 1864805408720
# _TableStyle('Dark List Accent 6') id: 1864806782608
# _TableStyle('Colorful Shading') id: 1864805408720
# _TableStyle('Colorful Shading Accent 1') id: 1864806782608
# _TableStyle('Colorful Shading Accent 2') id: 1864805408720
# _TableStyle('Colorful Shading Accent 3') id: 1864806782608
# _TableStyle('Colorful Shading Accent 4') id: 1864805408720
# _TableStyle('Colorful Shading Accent 5') id: 1864806782608
# _TableStyle('Colorful Shading Accent 6') id: 1864805408720
# _TableStyle('Colorful List') id: 1864806782608
# _TableStyle('Colorful List Accent 1') id: 1864805408720
# _TableStyle('Colorful List Accent 2') id: 1864806782608
# _TableStyle('Colorful List Accent 3') id: 1864805408720
# _TableStyle('Colorful List Accent 4') id: 1864806782608
# _TableStyle('Colorful List Accent 5') id: 1864805408720
# _TableStyle('Colorful List Accent 6') id: 1864806782608
# _TableStyle('Colorful Grid') id: 1864805408720
# _TableStyle('Colorful Grid Accent 1') id: 1864806782608
# _TableStyle('Colorful Grid Accent 2') id: 1864805408720
# _TableStyle('Colorful Grid Accent 3') id: 1864806782608
# _TableStyle('Colorful Grid Accent 4') id: 1864805408720
# _TableStyle('Colorful Grid Accent 5') id: 1864806782608
# _TableStyle('Colorful Grid Accent 6') id: 1864805408720
# _ParagraphStyle('TestStyle') id: 1864806782608

# %%
# adding text with an specific style
# to do that you have to add a specific chunck of text in a different time

# creating empty document in Python
document = Document()

example = 'Hello World (Variable)'

# here is where you'll have to edit 
text = f"""Hello World 1!
Hello World 2!
"""

final_text = """
Hello World 3!
"""

paragraph = document.add_paragraph(text)
paragraph.add_run(example).bold = True
paragraph = document.add_paragraph(final_text)

# saving and creating docx in Word
document.save('text.docx')

# %%
# controling margins, alignment, and sections
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT

# creating empty document in Python
document = Document()

for section in document.sections:
    section.top_margin=Cm(0.5)
    section_bottom_margin = Cm(1)
    section.left_margin = Cm(1)
    section.right_margin = Cm(1)

example = 'Hello World (Variable)'

# here is where you'll have to edit 
text = f"""Hello World 1!
Hello World 2!
"""

final_text = """
Hello World 3!
"""

paragraph = document.add_paragraph(text)
paragraph.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER
paragraph.add_run(example).bold = True
paragraph = document.add_paragraph(final_text)

# saving and creating docx in Word
document.save('text.docx')

# %%
# inserting images

# creating empty document in Python
document = Document()

for section in document.sections:
    section.top_margin=Cm(0.5)
    section_bottom_margin = Cm(1)
    section.left_margin = Cm(1)
    section.right_margin = Cm(1)

example = 'Hello World (Variable)'

# here is where you'll have to edit 
text = f"""Hello World 1!
Hello World 2!
"""

final_text = """
Hello World 3!
"""

paragraph = document.add_paragraph(text)
paragraph.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER
paragraph.add_run(example).bold = True
paragraph = document.add_paragraph(final_text)

image = document.add_picture('imagem.png', width=Cm(4), height=Cm(4))

# saving and creating docx in Word
document.save('text.docx')

# %%
# inserting tables

# creating empty document in Python
document = Document()

records = (
    (3, '101', 'Spam'),
    (7, '422', 'Eggs'),
    (4, '631', 'Spam, spam, eggs, and spam')
)

table = document.add_table(rows=1, cols=3, style='Light Grid Accent 1')
hdr_cells = table.rows[0].cells
hdr_cells[0].text = 'Qty'
hdr_cells[1].text = 'Id'
hdr_cells[2].text = 'Desc'
for qty, id, desc in records:
    row_cells = table.add_row().cells
    row_cells[0].text = str(qty)
    row_cells[1].text = id
    row_cells[2].text = desc

document.add_page_break()

document.save('demo.docx')

# and if we want to change the sheet style?

# %%
# checking for new sheet styles
for style in document.styles:
    print(style)
# Out:
# _ParagraphStyle('Normal') id: 1864808741648
# _ParagraphStyle('Header') id: 1864806782608
# <docx.styles.style.CharacterStyle object at 0x000001B22FC501D0>
# _ParagraphStyle('Footer') id: 1864806782608
# <docx.styles.style.CharacterStyle object at 0x000001B22FC501D0>
# _ParagraphStyle('Heading 1') id: 1864806782608
# _ParagraphStyle('Heading 2') id: 1864817246672
# _ParagraphStyle('Heading 3') id: 1864806782608
# _ParagraphStyle('Heading 4') id: 1864817246672
# _ParagraphStyle('Heading 5') id: 1864806782608
# _ParagraphStyle('Heading 6') id: 1864817246672
# _ParagraphStyle('Heading 7') id: 1864806782608
# _ParagraphStyle('Heading 8') id: 1864817246672
# _ParagraphStyle('Heading 9') id: 1864806782608
# <docx.styles.style.CharacterStyle object at 0x000001B22FC501D0>
# _TableStyle('Normal Table') id: 1864806782608
# <docx.styles.style._NumberingStyle object at 0x000001B22FC501D0>
# _ParagraphStyle('No Spacing') id: 1864806782608
# <docx.styles.style.CharacterStyle object at 0x000001B22FC501D0>
# <docx.styles.style.CharacterStyle object at 0x000001B22F255690>
# <docx.styles.style.CharacterStyle object at 0x000001B22FC501D0>
# _ParagraphStyle('Title') id: 1864806782608
# <docx.styles.style.CharacterStyle object at 0x000001B22FC501D0>
# _ParagraphStyle('Subtitle') id: 1864806782608
# <docx.styles.style.CharacterStyle object at 0x000001B22FC501D0>
# _ParagraphStyle('List Paragraph') id: 1864806782608
# _ParagraphStyle('Body Text') id: 1864817246672
# <docx.styles.style.CharacterStyle object at 0x000001B22F255690>
# _ParagraphStyle('Body Text 2') id: 1864817246672
# <docx.styles.style.CharacterStyle object at 0x000001B22F255690>
# _ParagraphStyle('Body Text 3') id: 1864817246672
# <docx.styles.style.CharacterStyle object at 0x000001B22F255690>
# _ParagraphStyle('List') id: 1864817246672
# _ParagraphStyle('List 2') id: 1864806782608
# _ParagraphStyle('List 3') id: 1864817246672
# _ParagraphStyle('List Bullet') id: 1864806782608
# _ParagraphStyle('List Bullet 2') id: 1864817246672
# _ParagraphStyle('List Bullet 3') id: 1864806782608
# _ParagraphStyle('List Number') id: 1864817246672
# _ParagraphStyle('List Number 2') id: 1864806782608
# _ParagraphStyle('List Number 3') id: 1864817246672
# _ParagraphStyle('List Continue') id: 1864806782608
# _ParagraphStyle('List Continue 2') id: 1864817246672
# _ParagraphStyle('List Continue 3') id: 1864806782608
# _ParagraphStyle('macro') id: 1864817246672
# <docx.styles.style.CharacterStyle object at 0x000001B22F255690>
# _ParagraphStyle('Quote') id: 1864817246672
# <docx.styles.style.CharacterStyle object at 0x000001B22F255690>
# <docx.styles.style.CharacterStyle object at 0x000001B22FC501D0>
# <docx.styles.style.CharacterStyle object at 0x000001B22F255690>
# <docx.styles.style.CharacterStyle object at 0x000001B22FC501D0>
# <docx.styles.style.CharacterStyle object at 0x000001B22F255690>
# <docx.styles.style.CharacterStyle object at 0x000001B22FC501D0>
# <docx.styles.style.CharacterStyle object at 0x000001B22F255690>
# _ParagraphStyle('Caption') id: 1864817246672
# <docx.styles.style.CharacterStyle object at 0x000001B22F255690>
# <docx.styles.style.CharacterStyle object at 0x000001B22FC501D0>
# _ParagraphStyle('Intense Quote') id: 1864806782608
# <docx.styles.style.CharacterStyle object at 0x000001B22FC501D0>
# <docx.styles.style.CharacterStyle object at 0x000001B22F255690>
# <docx.styles.style.CharacterStyle object at 0x000001B22FC501D0>
# <docx.styles.style.CharacterStyle object at 0x000001B22F255690>
# <docx.styles.style.CharacterStyle object at 0x000001B22FC501D0>
# <docx.styles.style.CharacterStyle object at 0x000001B22F255690>
# _ParagraphStyle('TOC Heading') id: 1864817246672
# _TableStyle('Table Grid') id: 1864806782608
# _TableStyle('Light Shading') id: 1864817246672
# _TableStyle('Light Shading Accent 1') id: 1864806782608
# _TableStyle('Light Shading Accent 2') id: 1864817246672
# _TableStyle('Light Shading Accent 3') id: 1864806782608
# _TableStyle('Light Shading Accent 4') id: 1864817246672
# _TableStyle('Light Shading Accent 5') id: 1864806782608
# _TableStyle('Light Shading Accent 6') id: 1864817246672
# _TableStyle('Light List') id: 1864806782608
# _TableStyle('Light List Accent 1') id: 1864817246672
# _TableStyle('Light List Accent 2') id: 1864806782608
# _TableStyle('Light List Accent 3') id: 1864817246672
# _TableStyle('Light List Accent 4') id: 1864806782608
# _TableStyle('Light List Accent 5') id: 1864817246672
# _TableStyle('Light List Accent 6') id: 1864806782608
# _TableStyle('Light Grid') id: 1864817246672
# _TableStyle('Light Grid Accent 1') id: 1864806782608
# _TableStyle('Light Grid Accent 2') id: 1864817246672
# _TableStyle('Light Grid Accent 3') id: 1864806782608
# _TableStyle('Light Grid Accent 4') id: 1864817246672
# _TableStyle('Light Grid Accent 5') id: 1864806782608
# _TableStyle('Light Grid Accent 6') id: 1864817246672
# _TableStyle('Medium Shading 1') id: 1864806782608
# _TableStyle('Medium Shading 1 Accent 1') id: 1864817246672
# _TableStyle('Medium Shading 1 Accent 2') id: 1864806782608
# _TableStyle('Medium Shading 1 Accent 3') id: 1864817246672
# _TableStyle('Medium Shading 1 Accent 4') id: 1864806782608
# _TableStyle('Medium Shading 1 Accent 5') id: 1864817246672
# _TableStyle('Medium Shading 1 Accent 6') id: 1864806782608
# _TableStyle('Medium Shading 2') id: 1864817246672
# _TableStyle('Medium Shading 2 Accent 1') id: 1864806782608
# _TableStyle('Medium Shading 2 Accent 2') id: 1864817246672
# _TableStyle('Medium Shading 2 Accent 3') id: 1864806782608
# _TableStyle('Medium Shading 2 Accent 4') id: 1864817246672
# _TableStyle('Medium Shading 2 Accent 5') id: 1864806782608
# _TableStyle('Medium Shading 2 Accent 6') id: 1864817246672
# _TableStyle('Medium List 1') id: 1864806782608
# _TableStyle('Medium List 1 Accent 1') id: 1864817246672
# _TableStyle('Medium List 1 Accent 2') id: 1864806782608
# _TableStyle('Medium List 1 Accent 3') id: 1864817246672
# _TableStyle('Medium List 1 Accent 4') id: 1864806782608
# _TableStyle('Medium List 1 Accent 5') id: 1864817246672
# _TableStyle('Medium List 1 Accent 6') id: 1864806782608
# _TableStyle('Medium List 2') id: 1864817246672
# _TableStyle('Medium List 2 Accent 1') id: 1864806782608
# _TableStyle('Medium List 2 Accent 2') id: 1864817246672
# _TableStyle('Medium List 2 Accent 3') id: 1864806782608
# _TableStyle('Medium List 2 Accent 4') id: 1864817246672
# _TableStyle('Medium List 2 Accent 5') id: 1864806782608
# _TableStyle('Medium List 2 Accent 6') id: 1864817246672
# _TableStyle('Medium Grid 1') id: 1864806782608
# _TableStyle('Medium Grid 1 Accent 1') id: 1864817246672
# _TableStyle('Medium Grid 1 Accent 2') id: 1864806782608
# _TableStyle('Medium Grid 1 Accent 3') id: 1864817246672
# _TableStyle('Medium Grid 1 Accent 4') id: 1864806782608
# _TableStyle('Medium Grid 1 Accent 5') id: 1864817246672
# _TableStyle('Medium Grid 1 Accent 6') id: 1864806782608
# _TableStyle('Medium Grid 2') id: 1864817246672
# _TableStyle('Medium Grid 2 Accent 1') id: 1864806782608
# _TableStyle('Medium Grid 2 Accent 2') id: 1864817246672
# _TableStyle('Medium Grid 2 Accent 3') id: 1864806782608
# _TableStyle('Medium Grid 2 Accent 4') id: 1864817246672
# _TableStyle('Medium Grid 2 Accent 5') id: 1864806782608
# _TableStyle('Medium Grid 2 Accent 6') id: 1864817246672
# _TableStyle('Medium Grid 3') id: 1864806782608
# _TableStyle('Medium Grid 3 Accent 1') id: 1864817246672
# _TableStyle('Medium Grid 3 Accent 2') id: 1864806782608
# _TableStyle('Medium Grid 3 Accent 3') id: 1864817246672
# _TableStyle('Medium Grid 3 Accent 4') id: 1864806782608
# _TableStyle('Medium Grid 3 Accent 5') id: 1864817246672
# _TableStyle('Medium Grid 3 Accent 6') id: 1864806782608
# _TableStyle('Dark List') id: 1864817246672
# _TableStyle('Dark List Accent 1') id: 1864806782608
# _TableStyle('Dark List Accent 2') id: 1864817246672
# _TableStyle('Dark List Accent 3') id: 1864806782608
# _TableStyle('Dark List Accent 4') id: 1864817246672
# _TableStyle('Dark List Accent 5') id: 1864806782608
# _TableStyle('Dark List Accent 6') id: 1864817246672
# _TableStyle('Colorful Shading') id: 1864806782608
# _TableStyle('Colorful Shading Accent 1') id: 1864817246672
# _TableStyle('Colorful Shading Accent 2') id: 1864806782608
# _TableStyle('Colorful Shading Accent 3') id: 1864817246672
# _TableStyle('Colorful Shading Accent 4') id: 1864806782608
# _TableStyle('Colorful Shading Accent 5') id: 1864817246672
# _TableStyle('Colorful Shading Accent 6') id: 1864806782608
# _TableStyle('Colorful List') id: 1864817246672
# _TableStyle('Colorful List Accent 1') id: 1864806782608
# _TableStyle('Colorful List Accent 2') id: 1864817246672
# _TableStyle('Colorful List Accent 3') id: 1864806782608
# _TableStyle('Colorful List Accent 4') id: 1864817246672
# _TableStyle('Colorful List Accent 5') id: 1864806782608
# _TableStyle('Colorful List Accent 6') id: 1864817246672
# _TableStyle('Colorful Grid') id: 1864806782608
# _TableStyle('Colorful Grid Accent 1') id: 1864817246672
# _TableStyle('Colorful Grid Accent 2') id: 1864806782608
# _TableStyle('Colorful Grid Accent 3') id: 1864817246672
# _TableStyle('Colorful Grid Accent 4') id: 1864806782608
# _TableStyle('Colorful Grid Accent 5') id: 1864817246672
# _TableStyle('Colorful Grid Accent 6') id: 1864806782608

# %%
from datetime import datetime

contract = Document('Contrato.docx')

# adapt a document
name = 'Jose Almeida'
item1 = 'Trainning service Almeida'
item2 = 'Completed material'
item3 = 'Trainning service Almeida'

# time variables
day = str(datetime.now().day)
month= str(datetime.now().month)
year= str(datetime.now().year)

# creating a dictionary
dict_values = {
    'XXXX': name,
    'YYYY': item1,
    'ZZZZ': item2,
    'WWWW': item3,
    'DD': day,
    'MM': month,
    'AAAA': year
}

# replacing codes 
for paragraph in contract.paragraphs:
    # for loop for each code
    for code in dict_values:
        if code in paragraph.text:
            paragraph.text = paragraph.text.replace(code, dict_values[code])
    
contract.save(f'Contrato_updated_client_{name}.docx')
